# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ## Extract CSVs into DataFrames
# Here we retrived the data from this website:
#
# https://www.census.gov/data/tables/time-series/demo/income-poverty/cps-pov/pov-01.html

# %%
csv_file = "race.csv"
race_data_df = pd.read_csv(csv_file)
race_data_df.head()
# Out:
#   All Races \n Below 100% All \n income \n levels  \
# 0               Total (1)                 322,549
# 1        ..Under 18 years                  73,356
# 2   ....Under 5 years (1)                  19,750
# 3       ....5 to 17 years                  53,606
# 4        ..18 to 64 years                 198,113
#
#   Below \n 100% of \n poverty (5)  \
# 0                          39,698
# 1                          12,808
# 2                           3,865
# 3                           8,942
# 4                          22,209
#
#    Percentage \n below 100% of \n poverty \n (6) All \n income \n levels.1  \
# 0                                           12.3                   260,709
# 1                                           17.5                    72,685
# 2                                           19.6                    19,660
# 3                                           16.7                    53,025
# ...

# %%
race_data_df.columns

race_data_df = race_data_df.rename(columns={'All Races \n Below 100%': 'Age_Range', 'All \n income \n levels': 'Income_Range'})

race_data_df.head()
# Out:
#                Age_Range Income_Range Below \n 100% of \n poverty (5)  \
# 0              Total (1)      322,549                          39,698
# 1       ..Under 18 years       73,356                          12,808
# 2  ....Under 5 years (1)       19,750                           3,865
# 3      ....5 to 17 years       53,606                           8,942
# 4       ..18 to 64 years      198,113                          22,209
#
#    Percentage \n below 100% of \n poverty \n (6) All \n income \n levels.1  \
# 0                                           12.3                   260,709
# 1                                           17.5                    72,685
# 2                                           19.6                    19,660
# 3                                           16.7                    53,025
# 4                                           11.2                   153,082
#
#   Below \n 100% of \n poverty (5).1  \
# 0                            26,766
# ...

# %% [markdown]
# ## Extract CSVs into DataFrames
# Here we retrived the data from another website:
#
# https://deathpenaltyinfo.org/2017-sentencing

# %%
csv_file = "execution_data.csv"
execution_data_df = pd.read_csv(csv_file)
execution_data_df.head()

execution_data_df.head()
# Out:
#       Date             Name  Age Sex    Race  \
# 0  1/10/86      James Roach   25   m   White
# 1  1/11/85      Joseph Shaw   29   m   White
# 2   1/8/97        Paul Ruiz   49   m  Latino
# 3   1/8/97  Earl Van Denton   47   m   White
# 4   1/6/94      Keith Wells   31   m   White
#
#      Number / Race / Sex of Victims State Region            Method Juvenile  \
# 0  1 White Male(s)1 White Female(s)    SC      S     Electrocution      Yes
# 1  1 White Male(s)1 White Female(s)    SC      S     Electrocution       No
# 2                   2 White Male(s)    AR      S  Lethal Injection       No
# 3                   2 White Male(s)    AR      S  Lethal Injection       No
# 4  1 White Male(s)1 White Female(s)    ID      W  Lethal Injection       No
#
#   Federal Volunteer Foreign National    County
# 0      No        No               No  Richland
# 1      No        No               No  Richland
# 2      No        No               No     Logan
# ...

# %% [markdown]
# ## Renaming the data to combine

# %%
race_data_df = race_data_df[["Age_Range", "Income_Range"]].copy()

# %%
#dropped first 5 row based on index due to being 18 years and under
race_data_df.drop(df.index[:5], inplace=True)
race_data_df
# Out:
#                 Age_Range Income_Range
# 5      ....18 to 24 years       29,363
# 6      ....25 to 34 years       44,854
# 7      ....35 to 44 years       40,659
# 8      ....45 to 54 years       41,537
# 9      ....55 to 59 years       21,622
# 10     ....60 to 64 years       20,078
# 11    ..65 years and over       51,080
# 12     ....65 to 74 years       30,367
# 13  ....75 years and over       20,713

# %%
def renaming_stuff(x):
    if x == '....18 to 24 years':
        return 'between 18 to 24'
    elif x == '....25 to 34 years':
        return 'between 25 to 34'
    elif x == '....35 to 44 years':
        return 'between 36 to 44'
    elif x == "....45 to 54 years":
        return 'between 46 to 54'
    elif x == "....55 to 59 years":
        return 'between 56 to 59'
    elif x == "....60 to 64 years":
        return 'between 61 to 64'
    elif x == "....65 to 74 years":
        return 'between 66 to 74'
    else:
        return x

race_data_df['newname'] = race_data_df['Age_Range'].apply(renaming_stuff)
race_data_df
# Out:
#                 Age_Range Income_Range                newname
# 5      ....18 to 24 years       29,363       between 18 to 24
# 6      ....25 to 34 years       44,854       between 25 to 34
# 7      ....35 to 44 years       40,659       between 36 to 44
# 8      ....45 to 54 years       41,537       between 46 to 54
# 9      ....55 to 59 years       21,622       between 56 to 59
# 10     ....60 to 64 years       20,078       between 61 to 64
# 11    ..65 years and over       51,080    ..65 years and over
# 12     ....65 to 74 years       30,367       between 66 to 74
# 13  ....75 years and over       20,713  ....75 years and over

# %%
execution_data_df[["Date", "Name", "Age", "Sex", "Race"]].head()
# Out:
#       Date             Name  Age Sex    Race
# 0  1/10/86      James Roach   25   m   White
# 1  1/11/85      Joseph Shaw   29   m   White
# 2   1/8/97        Paul Ruiz   49   m  Latino
# 3   1/8/97  Earl Van Denton   47   m   White
# 4   1/6/94      Keith Wells   31   m   White

# %%
df = execution_data_df[["Date", "Name", "Age", "Sex", "Race"]].copy()

# %% [markdown]
# ## Removing Null Values

# %%
 df = df.dropna()

# %%
df.Age.dtypes
# Out:
# dtype('int64')

# %%
def renaming_stuff2(x):
    if x <= 24:
        return 'between 18 to 24'
    elif x > 24 and x <= 34:
        return 'between 25 to 34'
    elif x > 34 and x <= 44:
        return 'between 36 to 44'
    elif x > 44 and x <= 54:
        return 'between 45 to 54'
    elif x > 54 and x <= 59:
        return 'between 56 to 59'
    elif x > 59 and x <= 64:
        return 'between 61 to 64'
    elif x > 64 and x <= 74:
        return 'between 66 to 74'
    else:
        return None

df['newname'] = df['Age'].apply(renaming_stuff2)

# %%
df['newname'].value_counts()
# Out:
# between 36 to 44    595
# between 25 to 34    366
# between 45 to 54    358
# between 56 to 59     85
# between 61 to 64     57
# between 66 to 74     19
# between 18 to 24      8
# Name: newname, dtype: int64

# %%
df_merged = pd.merge(df, race_data_df, on=['newname'])
df_merged_copy = df_merged[['Date', 'Name', 'Age', 'Sex', 'Race', 'newname', 'Income_Range']].copy()

# %%
df_merged_copy.dropna(inplace=True)

# %%
df_merged_copy.to_csv('cleaned.csv')

# %% [markdown]
# ## Create database connection

# %%
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine, MetaData
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Numeric, Text, Float, ForeignKey
from sqlalchemy.orm import sessionmaker, relationship

# %%
# Create Engine
engine = create_engine("mysql+pymysql://root:Biscuit2428!@127.0.0.1:3306/PROJECT2", pool_recycle=3600)

# %%
# Declare a Base object here
Base = declarative_base()

# %%
#Definding ORM class for `Measurements` table
class Prisoners(Base):
    
    __tablename__ = 'Prisoners'

    id = Column(Integer, primary_key=True)
    Date = Column(Text)
    Name = Column(Text)
    Age = Column(Integer)
    Sex = Column(Text)
    Race = Column(Text)
    newname = Column(Text)
    Income_Range = Column(Text)
    def __repr__(self):
        return f"id={self.id}, name={self.prisoner}"
    
# Date            object
# Name            object
# Age              int64
# Sex             object
# Race            object
# newname         object
# Income_Range    object

# %%
# Creating the tables using the 'engine'
Base.metadata.create_all(engine)

# %%
# Verify that the table names exist in the database
engine.table_names()
# Out:
# ['Prisoners']

# %%
df_of_data_to_insert = pd.read_csv('cleaned.csv')

conn = engine.connect()

#changing data into dictionary
data = df_of_data_to_insert.to_dict(orient='records')


#pointing to my table
my_table = Prisoners.__table__


#adding data to the database
conn.execute(my_table.insert(), data)
